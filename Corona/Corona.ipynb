# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from torch.autograd import Variable
import torch.utils.data as Data
# %matplotlib inline

# %% [markdown]
# # Read the data
# The first step of any data science program is to analyze the data, so what we need to do is to get the insights of the data because that's pretty crucial.
# First thing we are gonna do is use pandas to read the data, and analyze it.

# %%
df = pd.read_csv('2019_nCoV_data.csv')
df.head(5)
# Out:
#    Sno                 Date Province/State Country          Last Update  \
# 0    1  01/22/2020 12:00:00          Anhui   China  2020-01-22 12:00:00
# 1    2  01/22/2020 12:00:00        Beijing   China  2020-01-22 12:00:00
# 2    3  01/22/2020 12:00:00      Chongqing   China  2020-01-22 12:00:00
# 3    4  01/22/2020 12:00:00         Fujian   China  2020-01-22 12:00:00
# 4    5  01/22/2020 12:00:00          Gansu   China  2020-01-22 12:00:00
#
#    Confirmed  Deaths  Recovered
# 0        1.0     0.0        0.0
# 1       14.0     0.0        0.0
# 2        6.0     0.0        0.0
# 3        1.0     0.0        0.0
# 4        0.0     0.0        0.0

# %%
df.describe()
# Out:
#              Sno     Confirmed      Deaths   Recovered
# count  700.00000    700.000000  700.000000  700.000000
# mean   350.50000    141.224286    3.077143    3.407143
# std    202.21688    859.834237   27.759694   22.586377
# min      1.00000      0.000000    0.000000    0.000000
# 25%    175.75000      2.000000    0.000000    0.000000
# 50%    350.50000      8.000000    0.000000    0.000000
# 75%    525.25000     55.250000    0.000000    1.000000
# max    700.00000  13522.000000  414.000000  396.000000

# %%
df.isna().sum()
# Out:
# Sno                 0
# Date                0
# Province/State    164
# Country             0
# Last Update         0
# Confirmed           0
# Deaths              0
# Recovered           0
# dtype: int64

# %% [markdown]
# # Get Maximum Confirmed death records
# We will take a look at those places where there are maximum confirmed kills by this deadly virus.
# Both Countrywise and Province/State wise

# %%
df[df['Confirmed']>141.224286]
# Out:
#      Sno                 Date Province/State         Country  \
# 13    14  01/22/2020 12:00:00          Hubei           China
# 51    52  01/23/2020 12:00:00          Hubei  Mainland China
# 83    84  01/24/2020 12:00:00          Hubei  Mainland China
# 124  125  01/25/2020 22:00:00          Hubei  Mainland China
# 168  169  01/26/2020 23:00:00          Hubei  Mainland China
# ..   ...                  ...            ...             ...
# 642  643  02/03/2020 21:40:00        Beijing  Mainland China
# 643  644  02/03/2020 21:40:00       Shanghai  Mainland China
# 644  645  02/03/2020 21:40:00         Fujian  Mainland China
# 645  646  02/03/2020 21:40:00   Heilongjiang  Mainland China
# 646  647  02/03/2020 21:40:00        Shaanxi  Mainland China
#
#              Last Update  Confirmed  Deaths  Recovered
# 13   2020-01-22 12:00:00      444.0     0.0        0.0
# 51   2020-01-23 12:00:00      444.0    17.0       28.0
# 83   2020-01-24 12:00:00      549.0    24.0       31.0
# 124  2020-01-25 22:00:00     1052.0    52.0       42.0
# 168  2020-01-26 23:00:00     1423.0    76.0       44.0
# ..                   ...        ...     ...        ...
# 642  2020-03-02 09:23:00      212.0     1.0       12.0
# 643  2020-04-02 00:13:00      208.0     1.0       10.0
# 644  2020-03-02 11:33:00      179.0     0.0        1.0
# 645  2020-04-02 00:53:00      155.0     2.0        2.0
# 646  2020-04-02 02:33:00      142.0     0.0        1.0
#
# [94 rows x 8 columns]

# %%
df[df['Confirmed']>141.224286].Country.unique()
# Out:
# array(['China', 'Mainland China'], dtype=object)

# %%
df[df['Confirmed']>141.224286]["Province/State"].unique()
# Out:
# array(['Hubei', 'Guangdong', 'Zhejiang', 'Henan', 'Hunan', 'Anhui',
#        'Chongqing', 'Jiangxi', 'Shandong', 'Sichuan', 'Jiangsu',
#        'Shanghai', 'Beijing', 'Fujian', 'Heilongjiang', 'Shaanxi'],
#       dtype=object)

# %%
regionwise = df.groupby(["Province/State"])['Confirmed'].mean().reset_index()
regionwise = regionwise.sort_values('Confirmed', ascending=False)
regionwise
# Out:
#       Province/State    Confirmed
# 20             Hubei  4730.615385
# 55          Zhejiang   345.923077
# 12         Guangdong   305.461538
# 18             Henan   255.384615
# 21             Hunan   234.230769
# 0              Anhui   178.076923
# 25           Jiangxi   164.153846
# 9          Chongqing   154.923077
# 44           Sichuan   123.230769
# 41          Shandong   121.615385
# 24           Jiangsu   118.615385
# 3            Beijing   101.461538
# 42          Shanghai    95.692308
# 10            Fujian    79.153846
# 13           Guangxi    65.230769
# 40           Shaanxi    56.923077
# 16             Hebei    54.000000
# 54            Yunnan    49.000000
# 17      Heilongjiang    47.307692
# 15            Hainan    38.307692
# 27          Liaoning    35.846154
# 43            Shanxi    29.923077
# 48           Tianjin    25.769231
# 11             Gansu    23.384615
# 14           Guizhou    17.923077
# 23    Inner Mongolia    14.615385
# 32           Ningxia    13.461538
# 26             Jilin    12.846154
# 53          Xinjiang    11.769231
# 19         Hong Kong     8.615385
# 46            Taiwan     6.307692
# 35           Qinghai     5.692308
# 30             Macau     5.384615
# 31   New South Wales     4.000000
# 2            Bavaria     4.000000
# 51          Victoria     2.500000
# 6         California     2.166667
# 36        Queensland     2.166667
# 37    San Benito, CA     2.000000
# 8        Chicago, IL     2.000000
# 45   South Australia     2.000000
# 50       Toronto, ON     2.000000
# 33           Ontario     1.875000
# 38   Santa Clara, CA     1.666667
# 22          Illinois     1.285714
# 5   British Columbia     1.000000
# 52        Washington     1.000000
# 4         Boston, MA     1.000000
# 1            Arizona     1.000000
# 47         Tempe, AZ     1.000000
# 29   Los Angeles, CA     1.000000
# 7            Chicago     1.000000
# 34        Orange, CA     1.000000
# 39       Seattle, WA     1.000000
# 28        London, ON     1.000000
# 49             Tibet     0.750000

# %%
regionwise.describe()
# Out:
#          Confirmed
# count    56.000000
# mean    135.165301
# std     630.472891
# min       0.750000
# 25%       1.968750
# 50%      12.307692
# 75%      68.711538
# max    4730.615385

# %%
regionwise_upmean = regionwise[regionwise['Confirmed'] > 135.165301]
regionwise_upmean
# Out:
#    Province/State    Confirmed
# 20          Hubei  4730.615385
# 55       Zhejiang   345.923077
# 12      Guangdong   305.461538
# 18          Henan   255.384615
# 21          Hunan   234.230769
# 0           Anhui   178.076923
# 25        Jiangxi   164.153846
# 9       Chongqing   154.923077

# %%
# plt.figure(figsize=(432,324))
plt.bar(regionwise_upmean['Province/State'].values, regionwise_upmean['Confirmed'].values)
# plt.show()
plt.savefig('Corona.png')

# %%
regionwise_downmean = regionwise[regionwise['Confirmed']<135.165301]
regionwise_downmean
# Out:
#       Province/State   Confirmed
# 44           Sichuan  123.230769
# 41          Shandong  121.615385
# 24           Jiangsu  118.615385
# 3            Beijing  101.461538
# 42          Shanghai   95.692308
# 10            Fujian   79.153846
# 13           Guangxi   65.230769
# 40           Shaanxi   56.923077
# 16             Hebei   54.000000
# 54            Yunnan   49.000000
# 17      Heilongjiang   47.307692
# 15            Hainan   38.307692
# 27          Liaoning   35.846154
# 43            Shanxi   29.923077
# 48           Tianjin   25.769231
# 11             Gansu   23.384615
# 14           Guizhou   17.923077
# 23    Inner Mongolia   14.615385
# 32           Ningxia   13.461538
# 26             Jilin   12.846154
# 53          Xinjiang   11.769231
# 19         Hong Kong    8.615385
# 46            Taiwan    6.307692
# 35           Qinghai    5.692308
# 30             Macau    5.384615
# 31   New South Wales    4.000000
# 2            Bavaria    4.000000
# 51          Victoria    2.500000
# 6         California    2.166667
# 36        Queensland    2.166667
# 37    San Benito, CA    2.000000
# 8        Chicago, IL    2.000000
# 45   South Australia    2.000000
# 50       Toronto, ON    2.000000
# 33           Ontario    1.875000
# 38   Santa Clara, CA    1.666667
# 22          Illinois    1.285714
# 5   British Columbia    1.000000
# 52        Washington    1.000000
# 4         Boston, MA    1.000000
# 1            Arizona    1.000000
# 47         Tempe, AZ    1.000000
# 29   Los Angeles, CA    1.000000
# 7            Chicago    1.000000
# 34        Orange, CA    1.000000
# 39       Seattle, WA    1.000000
# 28        London, ON    1.000000
# 49             Tibet    0.750000

# %%
df[df['Province/State'] =='Hubei']['Country']
# Out:
# 13              China
# 51     Mainland China
# 83     Mainland China
# 124    Mainland China
# 168    Mainland China
# 215    Mainland China
# 267    Mainland China
# 319    Mainland China
# 375    Mainland China
# 434    Mainland China
# 497    Mainland China
# 564    Mainland China
# 631    Mainland China
# Name: Country, dtype: object

# %% [markdown]
# # Analysis of the Data
# What we can infer from the above Analysis is the following points:
# * <mark>Hubei</mark> in China is the most affected State/Province by this virus with an average confirmed death toll of about <mark>4730.615385</mark>
# * There are <mark>8 Provinces/States in China</mark> which are most affected by this Corona Virus.
# * Most of the European State/Province are less affected by this virus.
# * Tibet is the least affected State/Province in our set of data.

# %%
df['Country'].loc[df['Province/State'].isna()]
# Out:
# 35           Japan
# 36        Thailand
# 37     South Korea
# 73           Japan
# 74        Thailand
#           ...
# 689        Finland
# 691          Nepal
# 692          Spain
# 693      Sri Lanka
# 694         Sweden
# Name: Country, Length: 164, dtype: object
